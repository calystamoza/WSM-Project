# %%
#@title Twitter Auth Token

twitter_auth_token = 'c7ba0b208b0b0dbb7cc1a2e005ed2de13f9a74b7'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in c:\users\calys\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\calys\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\calys\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\calys\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\calys\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'node' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Crawl Data

filename = 'fufufafa.csv'
search_keyword = 'fufufafa since:2024-08-01 until:2024-09-10 lang:id'
limit = 2000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# 'npx' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1835847615101243472  Tue Sep 17 23:55:49 +0000 2024               3
# 1     1836170303913009302  Tue Sep 17 23:55:41 +0000 2024               0
# 2     1835807033699999938  Tue Sep 17 23:55:11 +0000 2024               0
# 3     1836116467634545003  Tue Sep 17 23:55:00 +0000 2024               9
# 4     1835960764395667947  Tue Sep 17 23:54:58 +0000 2024               0
# ...                   ...                             ...             ...
# 1998  1835900467798278150  Tue Sep 17 04:35:55 +0000 2024               0
# 1999  1835456722347188319  Tue Sep 17 04:35:20 +0000 2024               0
# 2000  1835897261492203686  Tue Sep 17 04:35:09 +0000 2024               3
# 2001  1835315026674196903  Tue Sep 17 04:34:48 +0000 2024               0
# 2002  1835807033699999938  Tue Sep 17 04:34:48 +0000 2024               1
#
#                                               full_text               id_str  \
# 0     @UusRsd @msaid_didu Yuk ganyang Fufufafa sesua...  1836192364668588124
# 1     @kompascom Biasa....drama mulyono...pura2 kage...  1836192330896019567
# 2            @fufu__fafa Jamet menjijikkan. Mesum pula.  1836192205847114084
# 3     @satriohendri Nebeng temen...ato nebeng sopir ...  1836192161693602201
# 4     @andikamalreza kasian org ini.. model penakut....  1836192150792650817
# ...                                                 ...                  ...
# 1998                stop calling me fufufafa pleaseeeee  1835900467798278150
# 1999  @msaid_didu Nah ini tepat penamaan Prof Fufufa...  1835900321044033540
# 2000  @CutSarina5 Kirim Mulyono dan Fufufafa ke nega...  1835900273480605911
# 2001       @Rexthatch Fufufafa kenapa mukanya gitu sih   1835900186398245150
# 2002         @fufu__fafa Memang stress berat orang ini   1835900185492283397
#
#                                             image_url in_reply_to_screen_name  \
# 0                                                 NaN                  UusRsd
# 1                                                 NaN               kompascom
# 2                                                 NaN              fufu__fafa
# 3     https://pbs.twimg.com/media/GXt3CR9akAMVaUU.jpg            satriohendri
# 4                                                 NaN           andikamalreza
# ...                                               ...                     ...
# 1998                                              NaN                     NaN
# 1999                                              NaN              msaid_didu
# 2000                                              NaN              CutSarina5
# 2001                                              NaN               Rexthatch
# 2002                                              NaN              fufu__fafa
#
#      lang                        location  quote_count  reply_count  \
# 0      in                             NaN            0            0
# 1      in                             NaN            0            0
# 2      in  Jakarta Capital Region, Indone            0            0
# 3      in                             NaN            0            0
# 4      in                             NaN            0            0
# ...   ...                             ...          ...          ...
# 1998   in                             NaN            0            0
# 1999   in               Banten, Indonesia            0            0
# 2000   in                             NaN            0            0
# 2001   in                             NaN            0            0
# 2002   in                             NaN            0            0
#
#       retweet_count                                          tweet_url  \
# 0                 0  https://x.com/makelarcapres/status/18361923646...
# 1                 0  https://x.com/BantengDotID/status/183619233089...
# 2                 0  https://x.com/kucingtuabangka/status/183619220...
# 3                 0  https://x.com/BantengDotID/status/183619216169...
# 4                 0  https://x.com/bram24hugery/status/183619215079...
# ...             ...                                                ...
# 1998              0  https://x.com/fafaasabila/status/1835900467798...
# 1999              0  https://x.com/PermataWangi/status/183590032104...
# 2000              0  https://x.com/Aryanto0402/status/1835900273480...
# 2001              0  https://x.com/ur_kamada/status/183590018639824...
# 2002              0  https://x.com/Hernisah07/status/18359001854922...
#
#               user_id_str         username
# 0     1655621733548965889    makelarcapres
# 1     1758470098623553538     BantengDotID
# 2     1658730412720685056  kucingtuabangka
# 3     1758470098623553538     BantengDotID
# 4     1809583978195906560     bram24hugery
# ...                   ...              ...
# 1998  1809886121054326784      fafaasabila
# 1999   916594558955220992     PermataWangi
# 2000  1201105903782510593      Aryanto0402
# 2001  1413731525271511044        ur_kamada
# 2002  1827728614819065859       Hernisah07
#
# [2003 rows x 15 columns]

# %%
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 2003.
